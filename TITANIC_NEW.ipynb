# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_csv(r'/content/train.csv')
df1=pd.read_csv(r'/content/test.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0              1         0       3  ...   7.2500   NaN         S
# 1              2         1       1  ...  71.2833   C85         C
# 2              3         1       3  ...   7.9250   NaN         S
# 3              4         1       1  ...  53.1000  C123         S
# 4              5         0       3  ...   8.0500   NaN         S
# ..           ...       ...     ...  ...      ...   ...       ...
# 886          887         0       2  ...  13.0000   NaN         S
# 887          888         1       1  ...  30.0000   B42         S
# 888          889         0       3  ...  23.4500   NaN         S
# 889          890         1       1  ...  30.0000  C148         C
# 890          891         0       3  ...   7.7500   NaN         Q
#
# [891 rows x 12 columns]

# %%
df1
# Out:
#      PassengerId  Pclass  ... Cabin Embarked
# 0            892       3  ...   NaN        Q
# 1            893       3  ...   NaN        S
# 2            894       2  ...   NaN        Q
# 3            895       3  ...   NaN        S
# 4            896       3  ...   NaN        S
# ..           ...     ...  ...   ...      ...
# 413         1305       3  ...   NaN        S
# 414         1306       1  ...  C105        C
# 415         1307       3  ...   NaN        S
# 416         1308       3  ...   NaN        S
# 417         1309       3  ...   NaN        C
#
# [418 rows x 11 columns]

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df1.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
df.corr()
# Out:
#              PassengerId  Survived    Pclass  ...     SibSp     Parch      Fare
# PassengerId     1.000000 -0.005007 -0.035144  ... -0.057527 -0.001652  0.012658
# Survived       -0.005007  1.000000 -0.338481  ... -0.035322  0.081629  0.257307
# Pclass         -0.035144 -0.338481  1.000000  ...  0.083081  0.018443 -0.549500
# Age             0.036847 -0.077221 -0.369226  ... -0.308247 -0.189119  0.096067
# SibSp          -0.057527 -0.035322  0.083081  ...  1.000000  0.414838  0.159651
# Parch          -0.001652  0.081629  0.018443  ...  0.414838  1.000000  0.216225
# Fare            0.012658  0.257307 -0.549500  ...  0.159651  0.216225  1.000000
#
# [7 rows x 7 columns]

# %%
df1.corr()
# Out:
#              PassengerId    Pclass       Age     SibSp     Parch      Fare
# PassengerId     1.000000 -0.026751 -0.034102  0.003818  0.043080  0.008211
# Pclass         -0.026751  1.000000 -0.492143  0.001087  0.018721 -0.577147
# Age            -0.034102 -0.492143  1.000000 -0.091587 -0.061249  0.337932
# SibSp           0.003818  0.001087 -0.091587  1.000000  0.306895  0.171539
# Parch           0.043080  0.018721 -0.061249  0.306895  1.000000  0.230046
# Fare            0.008211 -0.577147  0.337932  0.171539  0.230046  1.000000

# %%
df_new=df.drop(['Name'], axis=1)

# %%
df_new
# Out:
#      PassengerId  Survived  Pclass  ...     Fare  Cabin  Embarked
# 0              1         0       3  ...   7.2500    NaN         S
# 1              2         1       1  ...  71.2833    C85         C
# 2              3         1       3  ...   7.9250    NaN         S
# 3              4         1       1  ...  53.1000   C123         S
# 4              5         0       3  ...   8.0500    NaN         S
# ..           ...       ...     ...  ...      ...    ...       ...
# 886          887         0       2  ...  13.0000    NaN         S
# 887          888         1       1  ...  30.0000    B42         S
# 888          889         0       3  ...  23.4500    NaN         S
# 889          890         1       1  ...  30.0000   C148         C
# 890          891         0       3  ...   7.7500    NaN         Q
#
# [891 rows x 11 columns]

# %%
df1_new= df.drop(['Name'], axis=1)

# %%
df1_new
# Out:
#      PassengerId  Survived  Pclass  ...     Fare  Cabin  Embarked
# 0              1         0       3  ...   7.2500    NaN         S
# 1              2         1       1  ...  71.2833    C85         C
# 2              3         1       3  ...   7.9250    NaN         S
# 3              4         1       1  ...  53.1000   C123         S
# 4              5         0       3  ...   8.0500    NaN         S
# ..           ...       ...     ...  ...      ...    ...       ...
# 886          887         0       2  ...  13.0000    NaN         S
# 887          888         1       1  ...  30.0000    B42         S
# 888          889         0       3  ...  23.4500    NaN         S
# 889          890         1       1  ...  30.0000   C148         C
# 890          891         0       3  ...   7.7500    NaN         Q
#
# [891 rows x 11 columns]

# %%
sex= pd.get_dummies(df['Sex'], drop_first= True)

# %%
sex1= pd.get_dummies(['Sex'], drop_first= True)

# %%
df_new= pd.concat([df_new,sex], axis=1)

# %%
df1_new= pd.concat([df_new,sex], axis=1)

# %%
df_new
# Out:
#      PassengerId  Survived  Pclass     Sex  ...     Fare  Cabin  Embarked male
# 0              1         0       3    male  ...   7.2500    NaN         S    1
# 1              2         1       1  female  ...  71.2833    C85         C    0
# 2              3         1       3  female  ...   7.9250    NaN         S    0
# 3              4         1       1  female  ...  53.1000   C123         S    0
# 4              5         0       3    male  ...   8.0500    NaN         S    1
# ..           ...       ...     ...     ...  ...      ...    ...       ...  ...
# 886          887         0       2    male  ...  13.0000    NaN         S    1
# 887          888         1       1  female  ...  30.0000    B42         S    0
# 888          889         0       3  female  ...  23.4500    NaN         S    0
# 889          890         1       1    male  ...  30.0000   C148         C    1
# 890          891         0       3    male  ...   7.7500    NaN         Q    1
#
# [891 rows x 12 columns]

# %%
df_new= df_new.rename(columns={'male':'gender'})

# %%
df1_new= df1_new.rename(columns={'male':'gender'})

# %%
df_new
# Out:
#      PassengerId  Survived  Pclass     Sex  ...     Fare  Cabin  Embarked gender
# 0              1         0       3    male  ...   7.2500    NaN         S      1
# 1              2         1       1  female  ...  71.2833    C85         C      0
# 2              3         1       3  female  ...   7.9250    NaN         S      0
# 3              4         1       1  female  ...  53.1000   C123         S      0
# 4              5         0       3    male  ...   8.0500    NaN         S      1
# ..           ...       ...     ...     ...  ...      ...    ...       ...    ...
# 886          887         0       2    male  ...  13.0000    NaN         S      1
# 887          888         1       1  female  ...  30.0000    B42         S      0
# 888          889         0       3  female  ...  23.4500    NaN         S      0
# 889          890         1       1    male  ...  30.0000   C148         C      1
# 890          891         0       3    male  ...   7.7500    NaN         Q      1
#
# ...

# %%
df1_new
# Out:
#      PassengerId  Survived  Pclass     Sex  ...  Cabin  Embarked gender gender
# 0              1         0       3    male  ...    NaN         S      1      1
# 1              2         1       1  female  ...    C85         C      0      0
# 2              3         1       3  female  ...    NaN         S      0      0
# 3              4         1       1  female  ...   C123         S      0      0
# 4              5         0       3    male  ...    NaN         S      1      1
# ..           ...       ...     ...     ...  ...    ...       ...    ...    ...
# 886          887         0       2    male  ...    NaN         S      1      1
# 887          888         1       1  female  ...    B42         S      0      0
# 888          889         0       3  female  ...    NaN         S      0      0
# 889          890         1       1    male  ...   C148         C      1      1
# 890          891         0       3    male  ...    NaN         Q      1      1
#
# [891 rows x 13 columns]

# %%
df_new= df_new.drop(['PassengerId'], axis=1)

# %%
df1_new= df1_new.drop(['PassengerId'], axis=1)

# %%
df_new
# Out:
#      Survived  Pclass     Sex   Age  ...     Fare  Cabin Embarked  gender
# 0           0       3    male  22.0  ...   7.2500    NaN        S       1
# 1           1       1  female  38.0  ...  71.2833    C85        C       0
# 2           1       3  female  26.0  ...   7.9250    NaN        S       0
# 3           1       1  female  35.0  ...  53.1000   C123        S       0
# 4           0       3    male  35.0  ...   8.0500    NaN        S       1
# ..        ...     ...     ...   ...  ...      ...    ...      ...     ...
# 886         0       2    male  27.0  ...  13.0000    NaN        S       1
# 887         1       1  female  19.0  ...  30.0000    B42        S       0
# 888         0       3  female   NaN  ...  23.4500    NaN        S       0
# 889         1       1    male  26.0  ...  30.0000   C148        C       1
# 890         0       3    male  32.0  ...   7.7500    NaN        Q       1
#
# [891 rows x 11 columns]

# %%
df_new= df_new.drop(['Sex'], axis=1)

# %%
df1_new= df1_new.drop(['Sex'], axis=1)

# %%
df_new
# Out:
#      Survived  Pclass   Age  SibSp  ...     Fare Cabin  Embarked gender
# 0           0       3  22.0      1  ...   7.2500   NaN         S      1
# 1           1       1  38.0      1  ...  71.2833   C85         C      0
# 2           1       3  26.0      0  ...   7.9250   NaN         S      0
# 3           1       1  35.0      1  ...  53.1000  C123         S      0
# 4           0       3  35.0      0  ...   8.0500   NaN         S      1
# ..        ...     ...   ...    ...  ...      ...   ...       ...    ...
# 886         0       2  27.0      0  ...  13.0000   NaN         S      1
# 887         1       1  19.0      0  ...  30.0000   B42         S      0
# 888         0       3   NaN      1  ...  23.4500   NaN         S      0
# 889         1       1  26.0      0  ...  30.0000  C148         C      1
# 890         0       3  32.0      0  ...   7.7500   NaN         Q      1
#
# [891 rows x 10 columns]

# %%
df1_new
# Out:
#      Survived  Pclass   Age  SibSp  ...  Cabin Embarked gender gender
# 0           0       3  22.0      1  ...    NaN        S      1      1
# 1           1       1  38.0      1  ...    C85        C      0      0
# 2           1       3  26.0      0  ...    NaN        S      0      0
# 3           1       1  35.0      1  ...   C123        S      0      0
# 4           0       3  35.0      0  ...    NaN        S      1      1
# ..        ...     ...   ...    ...  ...    ...      ...    ...    ...
# 886         0       2  27.0      0  ...    NaN        S      1      1
# 887         1       1  19.0      0  ...    B42        S      0      0
# 888         0       3   NaN      1  ...    NaN        S      0      0
# 889         1       1  26.0      0  ...   C148        C      1      1
# 890         0       3  32.0      0  ...    NaN        Q      1      1
#
# [891 rows x 11 columns]

# %%
xyz= df_new.pivot(columns='Pclass',values='Age')
xyz
# Out:
# Pclass     1     2     3
# 0        NaN   NaN  22.0
# 1       38.0   NaN   NaN
# 2        NaN   NaN  26.0
# 3       35.0   NaN   NaN
# 4        NaN   NaN  35.0
# ..       ...   ...   ...
# 886      NaN  27.0   NaN
# 887     19.0   NaN   NaN
# 888      NaN   NaN   NaN
# 889     26.0   NaN   NaN
# 890      NaN   NaN  32.0
#
# [891 rows x 3 columns]

# %%
xyz1= df1_new.pivot(columns='Pclass',values='Age')
xyz1
# Out:
# Pclass     1     2     3
# 0        NaN   NaN  22.0
# 1       38.0   NaN   NaN
# 2        NaN   NaN  26.0
# 3       35.0   NaN   NaN
# 4        NaN   NaN  35.0
# ..       ...   ...   ...
# 886      NaN  27.0   NaN
# 887     19.0   NaN   NaN
# 888      NaN   NaN   NaN
# 889     26.0   NaN   NaN
# 890      NaN   NaN  32.0
#
# [891 rows x 3 columns]

# %%
box= sns.boxplot(data=xyz)

# %%
def impute_age(cols):
    Age=cols[0]
    Pclass=cols[1]
    if pd.isnull(Age):
        if Pclass == 1:
            return 37
        elif Pclass == 2:
            return 29
        else:
            return 24
    else:
        return Age

# %%
df_new['Age']=df_new[["Age",'Pclass']].apply(impute_age,axis=1)

# %%
df_new
# Out:
#      Survived  Pclass   Age  SibSp  ...     Fare Cabin  Embarked gender
# 0           0       3  22.0      1  ...   7.2500   NaN         S      1
# 1           1       1  38.0      1  ...  71.2833   C85         C      0
# 2           1       3  26.0      0  ...   7.9250   NaN         S      0
# 3           1       1  35.0      1  ...  53.1000  C123         S      0
# 4           0       3  35.0      0  ...   8.0500   NaN         S      1
# ..        ...     ...   ...    ...  ...      ...   ...       ...    ...
# 886         0       2  27.0      0  ...  13.0000   NaN         S      1
# 887         1       1  19.0      0  ...  30.0000   B42         S      0
# 888         0       3  24.0      1  ...  23.4500   NaN         S      0
# 889         1       1  26.0      0  ...  30.0000  C148         C      1
# 890         0       3  32.0      0  ...   7.7500   NaN         Q      1
#
# [891 rows x 10 columns]

# %%
df_new.isnull().sum()
# Out:
# Survived      0
# Pclass        0
# Age           0
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# Cabin       687
# Embarked      2
# gender        0
# dtype: int64

# %%
df_new= df_new.dropna(subset=['Embarked'])
code= pd.get_dummies(df_new['Embarked'], prefix='embarked')
df_new= pd.concat([df_new, code], axis=1)
df_new.head(10)
# Out:
#    Survived  Pclass   Age  SibSp  ...  gender embarked_C  embarked_Q embarked_S
# 0         0       3  22.0      1  ...       1          0           0          1
# 1         1       1  38.0      1  ...       0          1           0          0
# 2         1       3  26.0      0  ...       0          0           0          1
# 3         1       1  35.0      1  ...       0          0           0          1
# 4         0       3  35.0      0  ...       1          0           0          1
# 5         0       3  24.0      0  ...       1          0           1          0
# 6         0       1  54.0      0  ...       1          0           0          1
# 7         0       3   2.0      3  ...       1          0           0          1
# 8         1       3  27.0      0  ...       0          0           0          1
# 9         1       2  14.0      1  ...       0          1           0          0
#
# [10 rows x 13 columns]

# %%
df_new['Cabin']= df_new['Cabin'].fillna('U')
df_new['Cabin']= df_new['Cabin'].apply(lambda x: x[0])
code= pd.get_dummies(df_new['Cabin'], prefix='Cabin')
df_new= pd.concat([df_new, code], axis=1)
df_new.head(10)
# Out:
#    Survived  Pclass   Age  SibSp  ...  Cabin_F Cabin_G  Cabin_T Cabin_U
# 0         0       3  22.0      1  ...        0       0        0       1
# 1         1       1  38.0      1  ...        0       0        0       0
# 2         1       3  26.0      0  ...        0       0        0       1
# 3         1       1  35.0      1  ...        0       0        0       0
# 4         0       3  35.0      0  ...        0       0        0       1
# 5         0       3  24.0      0  ...        0       0        0       1
# 6         0       1  54.0      0  ...        0       0        0       0
# 7         0       3   2.0      3  ...        0       0        0       1
# 8         1       3  27.0      0  ...        0       0        0       1
# 9         1       2  14.0      1  ...        0       0        0       1
#
# [10 rows x 22 columns]

# %%
df_new
# Out:
#      Survived  Pclass   Age  SibSp  ...  Cabin_F Cabin_G  Cabin_T Cabin_U
# 0           0       3  22.0      1  ...        0       0        0       1
# 1           1       1  38.0      1  ...        0       0        0       0
# 2           1       3  26.0      0  ...        0       0        0       1
# 3           1       1  35.0      1  ...        0       0        0       0
# 4           0       3  35.0      0  ...        0       0        0       1
# ..        ...     ...   ...    ...  ...      ...     ...      ...     ...
# 886         0       2  27.0      0  ...        0       0        0       1
# 887         1       1  19.0      0  ...        0       0        0       0
# 888         0       3  24.0      1  ...        0       0        0       1
# 889         1       1  26.0      0  ...        0       0        0       0
# 890         0       3  32.0      0  ...        0       0        0       1
#
# [889 rows x 22 columns]

# %%
df_new= df_new.drop(['Ticket'], axis=1)

# %%
df_new
# Out:
#      Survived  Pclass   Age  SibSp  ...  Cabin_F  Cabin_G Cabin_T Cabin_U
# 0           0       3  22.0      1  ...        0        0       0       1
# 1           1       1  38.0      1  ...        0        0       0       0
# 2           1       3  26.0      0  ...        0        0       0       1
# 3           1       1  35.0      1  ...        0        0       0       0
# 4           0       3  35.0      0  ...        0        0       0       1
# ..        ...     ...   ...    ...  ...      ...      ...     ...     ...
# 886         0       2  27.0      0  ...        0        0       0       1
# 887         1       1  19.0      0  ...        0        0       0       0
# 888         0       3  24.0      1  ...        0        0       0       1
# 889         1       1  26.0      0  ...        0        0       0       0
# 890         0       3  32.0      0  ...        0        0       0       1
#
# [889 rows x 21 columns]

# %%
sns.boxplot(data= df_new['Age'])

# %%
sns.barplot(data=df,x='Sex',y='Age')

# %%
sns.barplot(data=df,x='Pclass',y='Age')

# %%
sns.barplot(data=df, x='Embarked', y='Survived')

# %%
pqr = df[df['Embarked']=='S']

# %%
sns.barplot(data=pqr, x='Embarked',y='Survived')
